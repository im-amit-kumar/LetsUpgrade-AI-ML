# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titles.csv')
df_release_date = pd.read_csv("release_dates.csv")
df_cast = pd.read_csv("cast.csv")
df.head()
# Out:
#                   title  year
# 0    Tasveer Mere Sanam  1996
# 1              Only You  1994
# 2  El pueblo del terror  1970
# 3               Machine  2007
# 4                  MARy  2008

# %%
df.shape
# Out:
# (244914, 2)

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
print("Total Movies listed in movies dataset are ",len(df.title))
# Out:
# Total Movies listed in movies dataset are  244914

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
df['year'].min()
# Out:
# 1894

# %%
df_year = df.sort_values('year',ascending=True)

# %%
df.head(2)
# Out:
#                 title  year
# 0  Tasveer Mere Sanam  1996
# 1            Only You  1994

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
df["title"]=="Hamlet"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 244909    False
# 244910    False
# 244911    False
# 244912    False
# 244913    False
# Name: title, Length: 244914, dtype: bool

# %%
df[df["title"]=="Hamlet"]
# Out:
#          title  year
# 6422    Hamlet  2017
# 10637   Hamlet  1921
# 39916   Hamlet  1913
# 52521   Hamlet  1910
# 62000   Hamlet  2000
# 67406   Hamlet  1969
# 82130   Hamlet  1987
# 88065   Hamlet  2016
# 101728  Hamlet  1948
# 122827  Hamlet  1973
# 133921  Hamlet  1976
# 154029  Hamlet  2015
# 161324  Hamlet  1964
# 172640  Hamlet  1954
# 173033  Hamlet  2011
# 178222  Hamlet  1996
# 189093  Hamlet  2009
# 192142  Hamlet  1990
# 198234  Hamlet  1911
# 202025  Hamlet  2014

# %%
len(df[df["title"]=="Hamlet"])
# Out:
# 20

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
    df["title"]=="North by Northwest"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 244909    False
# 244910    False
# 244911    False
# 244912    False
# 244913    False
# Name: title, Length: 244914, dtype: bool

# %%
    df[df["title"]=="North by Northwest"]
# Out:
#                     title  year
# 74398  North by Northwest  1959

# %%
    len(df[df["title"]=="North by Northwest"])
# Out:
# 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
x=df[df["title"]=="Hamlet"].sort_values('year')

# %%
x.head(1)
# Out:
#         title  year
# 52521  Hamlet  1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
df[df["title"]=="Treasure Island"].sort_values('year')
# Out:
#                   title  year
# 55686   Treasure Island  1918
# 196514  Treasure Island  1920
# 141822  Treasure Island  1934
# 77354   Treasure Island  1950
# 65051   Treasure Island  1972
# 37238   Treasure Island  1973
# 173051  Treasure Island  1985
# 27076   Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
df["year"]== 1950
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 244909    False
# 244910    False
# 244911    False
# 244912    False
# 244913    False
# Name: year, Length: 244914, dtype: bool

# %%
df[df["year"]==1950]
# Out:
#                           title  year
# 189          La soif des hommes  1950
# 268            Sohrab at Rustum  1950
# 308                       Gemma  1950
# 314                Rasuna valea  1950
# 524          Trial Without Jury  1950
# ...                         ...   ...
# 244200               Inmaculada  1950
# 244362        Golden Salamander  1950
# 244440  Prisoners in Petticoats  1950
# 244470  The Golden Gloves Story  1950
# 244820                 Doctor X  1950
#
# [1113 rows x 2 columns]

# %%
len(df[df["year"]==1950])
# Out:
# 1113

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
df[df["year"]==1960]
# Out:
#                                    title  year
# 52                   Tayna Dimki Karmiya  1960
# 88                 Tres angelitos negros  1960
# 226                         Viuda de oro  1960
# 227                      Tao se feng yun  1960
# 590                 Mahallenin sevgilisi  1960
# ...                                  ...   ...
# 244366                  Trouble with Eve  1960
# 244555  Makrykostaioi kai Kondogiorgides  1960
# 244774                        Tall Story  1960
# 244781                         Telegrame  1960
# 244819                   Me importa poco  1960
#
# [1549 rows x 2 columns]

# %%
len(df[df["year"]==1960])
# Out:
# 1549

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
df_year = df.sort_values('year',ascending=True)

# %%
df_year["year"][1950:1961]
# Out:
# 51007     1915
# 1353      1915
# 49171     1915
# 202344    1915
# 230537    1915
# 76612     1915
# 225443    1916
# 42449     1916
# 217393    1916
# 57534     1916
# 116003    1916
# Name: year, dtype: int64

# %%
len(df_year["year"][1950:1961])
# Out:
# 11

# %%
df_year["year"][1950:1961].count()
# Out:
# 11

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
df[df["title"]=="Treasure Island"].sort_values('year')
# Out:
#                   title  year
# 55686   Treasure Island  1918
# 196514  Treasure Island  1920
# 141822  Treasure Island  1934
# 77354   Treasure Island  1950
# 65051   Treasure Island  1972
# 37238   Treasure Island  1973
# 173051  Treasure Island  1985
# 27076   Treasure Island  1999

# %%
xy =df["title"]=="Treasure Island"

# %%
x = df[xy]

# %%
x
# Out:
#                   title  year
# 27076   Treasure Island  1999
# 37238   Treasure Island  1973
# 55686   Treasure Island  1918
# 65051   Treasure Island  1972
# 77354   Treasure Island  1950
# 141822  Treasure Island  1934
# 173051  Treasure Island  1985
# 196514  Treasure Island  1920

# %%
x["year"]
# Out:
# 27076     1999
# 37238     1973
# 55686     1918
# 65051     1972
# 77354     1950
# 141822    1934
# 173051    1985
# 196514    1920
# Name: year, dtype: int64

# %%
df_release_date.head()
# Out:
#                     title  year      country        date
# 0   #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                   #BKKY  2016     Cambodia  2017-10-12
# 2                 #Beings  2015      Romania  2015-01-29
# 3               #Captured  2017          USA  2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines  2015-01-21

# %%
df_cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
b =    df_cast[df_cast["title"]=="Inception"]

# %%
a = b.iloc[:,2:4]

# %%
a
# Out:
#                          name     type
# 98153    Michael (III) August    actor
# 149008           Peter Basham    actor
# 183937           Tom Berenger    actor
# 197877               Ken Bhan    actor
# 260128         Virgile Bramly    actor
# ...                       ...      ...
# 3387147            Ellen Page  actress
# 3444628        Nicole Pulliam  actress
# 3473041    Lisa (II) Reynolds  actress
# 3480170         Talulah Riley  actress
# 3731263        Shannon Welles  actress
#
# [78 rows x 2 columns]

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
b.head()
# Out:
#             title  year                  name   type              character  \
# 98153   Inception  2010  Michael (III) August  actor          LAX Passenger
# 149008  Inception  2010          Peter Basham  actor  Fischer's Jet Captain
# 183937  Inception  2010          Tom Berenger  actor               Browning
# 197877  Inception  2010              Ken Bhan  actor       Mombasan Gambler
# 260128  Inception  2010        Virgile Bramly  actor         Bridge Sub Con
#
#            n
# 98153    NaN
# 149008  44.0
# 183937   8.0
# 197877   NaN
# 260128  29.0

# %%
b[b['n'].notnull()]
# Out:
#              title  year                  name     type  \
# 149008   Inception  2010          Peter Basham    actor
# 183937   Inception  2010          Tom Berenger    actor
# 260128   Inception  2010        Virgile Bramly    actor
# 326745   Inception  2010         Michael Caine    actor
# 333415   Inception  2010          Earl Cameron    actor
# 433867   Inception  2010         Nicolas Clerc    actor
# 444385   Inception  2010        Adam (IV) Cole    actor
# 517227   Inception  2010    Jean-Michel Dagory    actor
# 590576   Inception  2010     Leonardo DiCaprio    actor
# 709436   Inception  2010             Russ Fega    actor
# 737322   Inception  2010      Mark Fleischmann    actor
# 807795   Inception  2010        Michael Gaston    actor
# 812135   Inception  2010       Johnathan Geare    actor
# 832083   Inception  2010         Carl Gilliard    actor
# 833376   Inception  2010           Jack Gilroy    actor
# 859993   Inception  2010  Joseph Gordon-Levitt    actor
# ...

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
b[b['n'].isnull()]
# Out:
#              title  year                     name     type  \
# 98153    Inception  2010     Michael (III) August    actor
# 197877   Inception  2010                 Ken Bhan    actor
# 374661   Inception  2010            John Ceallach    actor
# 497161   Inception  2010             Garvin Cross    actor
# 684098   Inception  2010            Seve Esposito    actor
# 690634   Inception  2010      Marcus (II) Everett    actor
# 707642   Inception  2010  Zachary Christopher Fay    actor
# 836295   Inception  2010        Daniel Girondeaud    actor
# 1006636  Inception  2010          Andrew Hoagland    actor
# 1095095  Inception  2010          Charles Jarrell    actor
# 1108755  Inception  2010            Seong-hwan Jo    actor
# 1120184  Inception  2010          Alonzo F. Jones    actor
# 1189066  Inception  2010               Mobin Khan    actor
# 1248176  Inception  2010            Shunsaku Kud?    actor
# 1296268  Inception  2010         John (IX) Lawson    actor
# ...

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
north =    df_cast[df_cast["title"]=="North by Northwest"]

# %%
north
# Out:
#                       title  year               name     type  \
# 12668    North by Northwest  1959      Stanley Adams    actor
# 29122    North by Northwest  1959         Andy Albin    actor
# 56389    North by Northwest  1959       Don Anderson    actor
# 56610    North by Northwest  1959    Ernest Anderson    actor
# 95950    North by Northwest  1959  Malcolm Atterbury    actor
# ...                     ...   ...                ...      ...
# 3518333  North by Northwest  1959    Eva Marie Saint  actress
# 3577128  North by Northwest  1959        Doris Singh  actress
# 3599912  North by Northwest  1959       Helen Spring  actress
# 3739133  North by Northwest  1959      Susan Whitney  actress
# 3751311  North by Northwest  1959     Paula Winslowe  actress
#
#                                  character    n
# 12668                   Lieutenant Harding  NaN
# 29122                               Farmer  NaN
# 56389                               Worker  NaN
# ...

# %%
north =north[north['n'].notnull()]

# %%
north
# Out:
#                       title  year                  name     type  \
# 206471   North by Northwest  1959          Edward Binns    actor
# 356707   North by Northwest  1959        Leo G. Carroll    actor
# 464736   North by Northwest  1959       Philip Coolidge    actor
# 665768   North by Northwest  1959     Robert Ellenstein    actor
# 871426   North by Northwest  1959            Cary Grant    actor
# 1275337  North by Northwest  1959         Martin Landau    actor
# 1384780  North by Northwest  1959             Ken Lynch    actor
# 1457165  North by Northwest  1959           James Mason    actor
# 1508344  North by Northwest  1959         Patrick McVey    actor
# 1695173  North by Northwest  1959           Philip Ober    actor
# 1811387  North by Northwest  1959          Edward Platt    actor
# 2295714  North by Northwest  1959          Les Tremayne    actor
# 2447081  North by Northwest  1959         Adam Williams    actor
# ...

# %%
north = north.sort_values('n')

# %%
north
# Out:
#                       title  year                  name     type  \
# 871426   North by Northwest  1959            Cary Grant    actor
# 3518333  North by Northwest  1959       Eva Marie Saint  actress
# 1457165  North by Northwest  1959           James Mason    actor
# 3157232  North by Northwest  1959   Jessie Royce Landis  actress
# 356707   North by Northwest  1959        Leo G. Carroll    actor
# 3048272  North by Northwest  1959  Josephine Hutchinson  actress
# 1695173  North by Northwest  1959           Philip Ober    actor
# 1275337  North by Northwest  1959         Martin Landau    actor
# 2447081  North by Northwest  1959         Adam Williams    actor
# 1811387  North by Northwest  1959          Edward Platt    actor
# 665768   North by Northwest  1959     Robert Ellenstein    actor
# 2295714  North by Northwest  1959          Les Tremayne    actor
# 464736   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
Sleuth =    df_cast[df_cast["title"]=="Sleuth"]

# %%
x =Sleuth[Sleuth['year'] == 1972]

# %%
x = x.sort_values('n')

# %%
x.iloc[:,1:]
# Out:
#          year                name     type                   character    n
# 1705394  1972    Laurence Olivier    actor                 Andrew Wyke  1.0
# 326773   1972       Michael Caine    actor                 Milo Tindle  2.0
# 373876   1972      Alec Cawthorne    actor           Inspector Doppler  3.0
# 1465483  1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# 2724553  1972  Eve (III) Channing  actress             Marguerite Wyke  5.0
# 1448690  1972        Teddy Martin    actor      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
Sleuth =    df_cast[df_cast["title"]=="Sleuth"]

# %%
x =Sleuth[Sleuth['year'] == 2007]

# %%
x = x.sort_values('n')

# %%
x.iloc[:,1:]
# Out:
#          year                 name     type          character    n
# 326774   2007        Michael Caine    actor             Andrew  1.0
# 1293634  2007             Jude Law    actor               Milo  2.0
# 1805907  2007        Harold Pinter    actor        Man on T.V.  3.0
# 260242   2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 373877   2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2724552  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3370424  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
Hamlet =    df_cast[df_cast["title"]=="Hamlet"]

# %%
x = Hamlet[Hamlet['year']== 1921]

# %%
x
# Out:
#           title  year                    name     type         character    n
# 7789     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 458904   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 555034   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1135279  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2185558  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2375993  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2664423  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 3062023  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3355176  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %%
len(x.iloc[:,5])
# Out:
# 9

# %%
print("Total Roles were credited for 1921 Hamlet ",len(x.iloc[:,5]))
# Out:
# Total Roles were credited for 1921 Hamlet  9

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
Hamlet
# Out:
#           title  year              name     type              character     n
# 1731     Hamlet  1996        Riz Abbasi    actor  Attendant to Claudius   1.0
# 7789     Hamlet  1921  Fritz Achterberg    actor            Fortinbras,   9.0
# 11728    Hamlet  2009      Hayden Adams    actor                Laertes   7.0
# 11729    Hamlet  2009      Hayden Adams    actor                 Player   7.0
# 14493    Hamlet  1913       Eric Adeney    actor               Reynaldo  14.0
# ...         ...   ...               ...      ...                    ...   ...
# 3673234  Hamlet  1969    Jennifer Tudor  actress             Court lady  23.0
# 3697397  Hamlet  2000      Diane Venora  actress               Gertrude   3.0
# 3728751  Hamlet  1996     Perdita Weeks  actress          Second Player  44.0
# 3733637  Hamlet  2015   Katie (II) West  actress                Ophelia   7.0
# 3751232  Hamlet  1996      Kate Winslet  actress                Ophelia  46.0
#
# [342 rows x 6 columns]

# %%
x = Hamlet[Hamlet['year']== 1996]

# %%
len(x.iloc[:,5])
# Out:
# 54

# %%
print("Total Roles were credited for 1996 Hamlet ",len(x.iloc[:,5]))
# Out:
# Total Roles were credited for 1996 Hamlet  54

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
Hamlet.iloc[:,5]
# Out:
# 1731        1.0
# 7789        9.0
# 11728       7.0
# 11729       7.0
# 14493      14.0
#            ...
# 3673234    23.0
# 3697397     3.0
# 3728751    44.0
# 3733637     7.0
# 3751232    46.0
# Name: n, Length: 342, dtype: float64

# %%
print("Hamlet roles have been listed in all film credits through history ",len(Hamlet.iloc[:,5]))
# Out:
# Hamlet roles have been listed in all film credits through history  342

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
df_cast[df_cast['character'] == "Ophelia"]
# Out:
#                                                      title  year  \
# 248251                          The Merry Maids of Madness  2016
# 410247                                      Jake Gets Paid  2009
# 470859                                          Inoperable  2017
# 866334                     Dogg's Hamlet, Cahoot's Macbeth  2005
# 1364457                                                 11  2014
# ...                                                    ...   ...
# 3722298                                           D.C. Cab  1983
# 3723039                                           Creature  2011
# 3733637                                             Hamlet  2015
# 3748118  National Theatre Live: Rosencrantz & Guildenst...  2017
# 3751232                                             Hamlet  1996
#
#                          name     type character     n
# 248251            Amy Bourque    actor   Ophelia  11.0
# 410247         Josie Chisholm    actor   Ophelia   NaN
# ...

# %%
print("total people who played the role Ophelia are as follow",len(df_cast[df_cast['character'] == "Ophelia"]))
# Out:
# total people who played the role Ophelia are as follow 117

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
df_cast[df_cast['character'] == "The Dude"]
# Out:
#                                   title  year                  name   type  \
# 272161                 The Big Lebowski  1998          Jeff Bridges  actor
# 339389               Terms & Conditions  2015           Jordan Cann  actor
# 498660                         Stranger  2000         Scott Crowell  actor
# 570128           Pizza Man vs. the Dude  2004        Chris DeMarcus  actor
# 610791                      Sweepstakes  1931           Mike Donlin  actor
# 629473                    Self Helpless  2010        Devin The Dude  actor
# 855976                A Few Brains More  2012    Michael D. Goodwin  actor
# 1089444  Jay and Silent Bob Strike Back  2001   Matthew (XIX) James  actor
# 1138933                   Explicit Ills  2008    Christopher Kadish  actor
# 1367230                 American Idiots  2013      Jason Loughridge  actor
# 1386561             The Winds of Autumn  1976           Steve Lyons  actor
# ...

# %%
print("total people who played the role Ophelia are as follow",len(df_cast[df_cast['character'] == "The Dude"]))
# Out:
# total people who played the role Ophelia are as follow 19

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
y=len(df_cast[df_cast['character'] == "The Stranger"])

# %%
print("total people who played the role Ophelia are as follow",y)
# Out:
# total people who played the role Ophelia are as follow 212

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
x=df_cast[df_cast['name'] == "Sidney Poitier"]

# %%
x= x.iloc[:,5]

# %%
print("Sidney Plotter has played total roles =", len(x))
# Out:
# Sidney Plotter has played total roles = 43

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
x=df_cast[df_cast['name'] == "Judi Dench"]

# %%
x= x.iloc[:,5]

# %%
print("Judi Dench has played total roles =", len(x))
# Out:
# Judi Dench has played total roles = 55

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
df_cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
x =df_cast[df_cast["name"] == "Cary Grant"]

# %%
x = x.sort_values('year')

# %%
x
# Out:
#                             title  year        name   type  \
# 871419      Merrily We Go to Hell  1932  Cary Grant  actor
# 871418           Madame Butterfly  1932  Cary Grant  actor
# 871392               Blonde Venus  1932  Cary Grant  actor
# 871437         Sinners in the Sun  1932  Cary Grant  actor
# 871409               Hot Saturday  1932  Cary Grant  actor
# ...                           ...   ...         ...    ...
# 871462             Walk Don't Run  1966  Cary Grant  actor
# 871456              This Is Elvis  1981  Cary Grant  actor
# 871397  Dead Men Don't Wear Plaid  1982  Cary Grant  actor
# 871428      Nuovo Cinema Paradiso  1988  Cary Grant  actor
# 871461                     Trumbo  2015  Cary Grant  actor
#
#                           character     n
# 871419               Charlie Baxter   9.0
# 871418    Lieutenant B.F. Pinkerton   2.0
# 871392                Nick Townsend   3.0
# 871437                     Ridgeway   8.0
# ...

# %%
z=x[ (x['year']>=1930) & (x['year']<1940) ]

# %%
y =z[z["n"] ==2]

# %%
y
# Out:
#                          title  year        name   type  \
# 871418        Madame Butterfly  1932  Cary Grant  actor
# 871446  The Eagle and the Hawk  1933  Cary Grant  actor
# 871454       The Woman Accused  1933  Cary Grant  actor
# 871412            I'm No Angel  1933  Cary Grant  actor
# 871436      She Done Him Wrong  1933  Cary Grant  actor
# 871455     Thirty Day Princess  1934  Cary Grant  actor
# 871393          Born to Be Bad  1934  Cary Grant  actor
# 871401           Enter Madame!  1935  Cary Grant  actor
# 871440         Sylvia Scarlett  1935  Cary Grant  actor
# 871465       Wings in the Dark  1935  Cary Grant  actor
# 871463         Wedding Present  1936  Cary Grant  actor
# 871453   The Toast of New York  1937  Cary Grant  actor
# 871464     When You're in Love  1937  Cary Grant  actor
# 871443         The Awful Truth  1937  Cary Grant  actor
# 871459                  Topper  1937  Cary Grant  actor
# 871394        Bringing Up Baby  1938  Cary Grant  actor
# ...

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
x =df_cast[df_cast["name"] == "Cary Grant"]

# %%
x = x.sort_values('year')

# %%
z=x[ (x['year']>=1930) & (x['year']<1940) ]

# %%
y =z[z["n"] ==1]

# %%
y
# Out:
#                                     title  year        name   type  \
# 871409                       Hot Saturday  1932  Cary Grant  actor
# 871404                      Gambling Ship  1933  Cary Grant  actor
# 871417               Ladies Should Listen  1934  Cary Grant  actor
# 871415                   Kiss and Make-Up  1934  Cary Grant  actor
# 871449                   The Last Outpost  1935  Cary Grant  actor
# 871442  The Amazing Quest of Ernest Bliss  1936  Cary Grant  actor
# 871391                     Big Brown Eyes  1936  Cary Grant  actor
# 871431             Only Angels Have Wings  1939  Cary Grant  actor
# 871406                          Gunga Din  1939  Cary Grant  actor
#
#                 character    n
# 871409    Romer Sheffield  1.0
# 871404         Ace Corbin  1.0
# 871417   Julian De Lussac  1.0
# 871415  Dr. Maurice Lamar  1.0
# 871449    Michael Andrews  1.0
# 871442       Ernest Bliss  1.0
# 871391         Danny Barr  1.0
# 871431       Geoff Carter  1.0
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
z=df_cast[ (df_cast['year']>=1940) & (df_cast['year']<1950) ]

# %%
z=z[z["type"] == "actor"]

# %%
z
# Out:
#                          title  year                name   type  \
# 297      Kampen om tungtvannet  1948       Andreas Aabel  actor
# 304          Den farlige leken  1942           Per Aabel  actor
# 305          En herre med bart  1942           Per Aabel  actor
# 357            Villmarkens lov  1944  Karl Aagard ?stvig  actor
# 456          Ristikon varjossa  1945     Heikki Aaltoila  actor
# ...                        ...   ...                 ...    ...
# 2531754          Ungdom i fara  1946       Tom ?sterholm  actor
# 2531774                  Gatan  1949         Alf ?stlund  actor
# 2531780    Robinson i Roslagen  1948         Alf ?stlund  actor
# 2532389         Tyrannens Fald  1942        Anker ?rskov  actor
# 2532457  Kampen om tungtvannet  1948         ?yvind ?yen  actor
#
#                                 character     n
# 297                Kasper Idland - fenrik   8.0
# 304                  Fredrik Holm, doktor   NaN
# 305                    Ole Grong, advokat   1.0
# ...

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
z=df_cast[ (df_cast['year']>=1940) & (df_cast['year']<1950) ]

# %%
z=z[z["type"] == "actress"]

# %%
z
# Out:
#                                title  year               name     type  \
# 2532685             Around the World  1943  Lucienne & Ashour  actress
# 2532723               A Woman's Face  1941    Hauk (II) Aabel  actress
# 2532824       Along the Navajo Trail  1945      Marlene Aames  actress
# 2532825  The Best Years of Our Lives  1946      Marlene Aames  actress
# 2532826                The Big Clock  1948      Marlene Aames  actress
# ...                              ...   ...                ...      ...
# 3785999                  Jeg drepte!  1942       Synn?ve ?ian  actress
# 3786047             Sangen til livet  1943  Ragnhild ?sterbye  actress
# 3786053              Villmarkens lov  1944      Manina ?stvig  actress
# 3786055    En ganske almindelig pige  1940         Clara ?st?  actress
# 3786060     Tante Cramers testamente  1941         Clara ?st?  actress
#
#                          character     n
# 2532685             Apache Dancers   NaN
# ...

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
z=df_cast[ (df_cast['year']>=1980)  ]

# %%
z= z[z['n'] ==1]

# %%
z
# Out:
#                           title  year              name     type  \
# 102      Live Freaky Die Freaky  2006           Nick 13    actor
# 138       All Things Fall Apart  2011           50 Cent    actor
# 144                 Freelancers  2012           50 Cent    actor
# 145      Get Rich or Die Tryin'  2005           50 Cent    actor
# 146                         Gun  2010           50 Cent    actor
# ...                         ...   ...               ...      ...
# 3785961                  Kadife  2012      Ayta? ?ztuna  actress
# 3786008              Dig og mig  2008  Julie R. ?lgaard  actress
# 3786011    Fortune Defies Death  2017  Julie R. ?lgaard  actress
# 3786029      Mimi og madammerne  1998         Tammi ?st  actress
# 3786036               Ved vejen  1988         Tammi ?st  actress
#
#               character    n
# 102      TV Reporter #1  1.0
# 138                Deon  1.0
# 144                Malo  1.0
# 145              Marcus  1.0
# 146                Rich  1.0
# ...

# %%
len(z)
# Out:
# 89276

# %%
print("Total Leading roles in Film Industry from the begining of Film History through 1980 ",len(z))
# Out:
# Total Leading roles in Film Industry from the begining of Film History through 1980  89276

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
z=df_cast[ (df_cast['year']>=1980)  ]

# %%
z = z[z['n'] > 1 ]

# %%
z
# Out:
#                                                      title  year  \
# 0                                           Closet Monster  2015
# 1                                          Suuri illusioni  1985
# 2                                      Battle of the Sexes  2017
# 8        Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 10                                 When the Man Went South  2014
# ...                                                    ...   ...
# 3786170                                     Stuttur Frakki  1993
# 3786171                                            Foxtrot  1988
# 3786172                   Niceland (Population. 1.000.002)  2004
# 3786173                                          Skammdegi  1985
# 3786174                                       U.S.S.S.S...  2003
#
#                                 name     type               character     n
# 0                           Buffy #1    actor                 Buffy 4  31.0
# ...

# %%
print("Total non leading roles which were available through from the beginning of film history through 1980 " , len(z))
# Out:
# Total non leading roles which were available through from the beginning of film history through 1980  1522873

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
z=df_cast[ (df_cast['year']>=1980)  ]

# %%
z = z[z['n'].isnull() ]

# %%
z
# Out:
#                           title  year                         name     type  \
# 3          Secret in Their Eyes  2015                      $hutter    actor
# 4                    Steve Jobs  2015                      $hutter    actor
# 5        Straight Outta Compton  2015                      $hutter    actor
# 6        Straight Outta Compton  2015                      $hutter    actor
# 7                For Thy Love 2  2009                 Bee Moe $lim    actor
# ...                         ...   ...                          ...      ...
# 3786160               Svanurinn  2017      Katla M. ?orgeirsd?ttir  actress
# 3786166               Foreldrar  2007  Lilja Gu?r?n ?orvaldsd?ttir  actress
# 3786167                 Rokland  2011  Lilja Gu?r?n ?orvaldsd?ttir  actress
# 3786168                      XL  2013  Lilja Gu?r?n ?orvaldsd?ttir  actress
# 3786175       Bye Bye Blue Bird  1999                 Rosa ? R?gvu  actress
#
#                           character   n
# ...

# %%
print('roles through 1980 were minor enough that they did not warrant a numeric "n" rank is ',len(z))
# Out:
# roles through 1980 were minor enough that they did not warrant a numeric "n" rank is  1014692
